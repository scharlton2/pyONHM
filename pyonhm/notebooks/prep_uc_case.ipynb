# %% [markdown]
# # Prep Upper Colorado use-case.
#
# This a subset of the NHM prepped from a Bandit pull by Parker Norton.  Using this as a
# test case for forecasting.

# %%
import geopandas as gpd
import requests
import pandas as pd
import rioxarray

# %%
root_dir = '/mnt/d/oNHM/NHM_PRMS_UC_GF_1_1/'

# %%
root_dir
# Out:
# '/mnt/d/oNHM/NHM_PRMS_UC_GF_1_1/'

# %%
gdf = gpd.read_file(root_dir + "GIS/model_nhru.shp")
gdf
# Out:
#       nhm_id  model_hru_                                           geometry
# 0      83301         274  POLYGON ((-1324125.133 1609094.887, -1324275.0...
# 1      83302         275  POLYGON ((-1331914.568 1623225.112, -1331901.0...
# 2      83359         332  POLYGON ((-1308375.036 1622938.630, -1308465.2...
# 3      83364         337  POLYGON ((-1337655.210 1640205.133, -1337535.3...
# 4      83366         339  POLYGON ((-1339634.862 1640985.080, -1339695.0...
# ...      ...         ...                                                ...
# 3846   86611        3556  POLYGON ((-1256384.842 2032365.123, -1256295.1...
# 3847   86615        3560  POLYGON ((-1255034.951 2041934.777, -1255154.7...
# 3848   86686        3631  POLYGON ((-1244805.129 1970954.938, -1244744.9...
# 3849   86691        3636  POLYGON ((-1255664.885 1971375.143, -1255544.7...
# 3850   85616        2561  POLYGON ((-1263404.814 2001224.252, -1263361.8...
#
# [3851 rows x 3 columns]

# %%
# Find invalid geometries
invalid_geometries = gdf[~gdf.is_valid]
print(f"Found {len(invalid_geometries)} invalid geometries.")

# Correct invalid geometries by explicitly targeting the original DataFrame
gdf.loc[~gdf.is_valid, 'geometry'] = gdf.loc[~gdf.is_valid, 'geometry'].apply(lambda geom: geom.buffer(0))

# Re-check for invalid geometries after the correction
invalid_geometries_after = gdf[~gdf.is_valid]
print(f"Found {len(invalid_geometries_after)} invalid geometries after correction.")
# Out:
# Found 177 invalid geometries.
# Found 0 invalid geometries after correction.

# %%
gdf.crs
# Out:
# <Projected CRS: ESRI:102039>
# Name: USA_Contiguous_Albers_Equal_Area_Conic_USGS_version
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf = gdf.to_crs("EPSG:4326")
gdf
# Out:
#       nhm_id  model_hru_                                           geometry
# 0      83301         274  POLYGON ((-110.99899 36.58611, -111.00061 36.5...
# 1      83302         275  POLYGON ((-111.11099 36.69969, -111.11049 36.6...
# 2      83359         332  POLYGON ((-110.93996 36.75837, -110.94202 36.7...
# 3      83364         337  POLYGON ((-111.20558 36.84119, -111.20403 36.8...
# 4      83366         339  POLYGON ((-111.22911 36.84524, -111.22967 36.8...
# ...      ...         ...                                                ...
# 3846   86611        3556  POLYGON ((-110.99459 40.41116, -110.99353 40.4...
# 3847   86615        3560  POLYGON ((-110.99662 40.49742, -110.99808 40.4...
# 3848   86686        3631  POLYGON ((-110.74581 39.88584, -110.74506 39.8...
# 3849   86691        3636  POLYGON ((-110.87315 39.87450, -110.87142 39.8...
# 3850   85616        2561  POLYGON ((-111.01873 40.12680, -111.01790 40.1...
#
# [3851 rows x 3 columns]

# %% [markdown]
# ## Step 2: Sort the DataFrame by 'nhm_id'
# Looks like data are sorted already but we'll sort anyway. CBH data supplied to this model should be sorted by nhm_id.

# %%
gdf_sorted = gdf.sort_values(by="nhm_id")

# %% [markdown]
# ## Step 3: Export "nhm_id" to a file

# %%
gdf_sorted['nhm_id'].to_csv(root_dir + 'daily/input/nhm_id', index=False, header=False)

# %% [markdown]
# ## Step 4: Calculate and write hru centroids.

# %%
centroids = gdf_sorted.to_crs(5070).geometry.centroid
centroids_ll = centroids.to_crs(4326)
lats = centroids_ll.y
lons = centroids_ll.x
lats.to_csv(root_dir + 'daily/input/hru_lat.txt', index=False, header=False)
lons.to_csv(root_dir + 'daily/input/hru_lon.txt', index=False, header=False)

# %%
points = list(zip(lons, lats))
points[-10:]
# Out:
# [(-109.62181340109326, 42.67709827954675),
#  (-109.59178752024967, 42.65613676844921),
#  (-109.81231608672125, 42.97729605771425),
#  (-109.81068824830739, 42.98645822426993),
#  (-109.69921741978114, 43.16469746353956),
#  (-109.72782279994864, 43.1098871029577),
#  (-109.76548123574867, 43.120069767784976),
#  (-109.68778919598705, 43.1537152300935),
#  (-109.80477414799824, 43.17723475172029),
#  (-109.8228574876643, 43.18968847824578)]

# %% [markdown]
# ## 5 Get elevations - used for calculating humidity from cfsv2 data.

# %%
import rasterio
from rasterio.transform import rowcol
import numpy as np

# List of GeoTIFF files
tiff_files = ['/mnt/d/oNHM/gt30w100n40.tif', '/mnt/d/oNHM/gt30w100n90.tif', '/mnt/d/oNHM/gt30w140n40.tif', '/mnt/d/oNHM/gt30w140n90.tif']


# Function to find elevation for a single point
def get_elevation(lon, lat, datasets):
    for dataset in datasets:
        # Check if the point is within the bounds of this dataset
        if dataset.bounds[0] <= lon <= dataset.bounds[2] and dataset.bounds[1] <= lat <= dataset.bounds[3]:
            # Convert the lon/lat to row/col in the dataset
            row, col = rowcol(dataset.transform, lon, lat)
            # Read the elevation value at this row/col
            value = dataset.read(1)[row, col]
            return value
    return np.nan  # Return NaN if the point is not in any dataset

# Open all the TIFFs
datasets = [rasterio.open(tiff) for tiff in tiff_files]

# Get elevations for all points
elevations = [get_elevation(lon, lat, datasets) for lon, lat in points]

# Don't forget to close the datasets
for dataset in datasets:
    dataset.close()

print(elevations)
# Out:
# [1997, 1891, 2079, 1980, 2011, 2041, 2072, 1950, 1936, 1896, 2102, 1913, 1950, 1950, 1858, 1926, 1825, 1980, 1823, 1889, 1889, 2161, 1773, 1767, 1737, 1827, 1755, 1767, 1828, 1848, 1706, 1764, 1802, 1756, 1889, 2133, 1737, 2086, 2061, 2251, 1787, 2023, 2019, 2133, 2036, 1747, 1829, 1979, 1705, 2167, 2233, 2255, 1791, 2171, 1859, 1701, 1693, 1689, 1777, 1935, 1767, 1706, 1950, 2206, 1703, 1676, 1828, 2255, 1702, 1833, 1857, 1828, 1889, 2255, 1645, 1693, 1627, 1627, 1684, 1755, 1706, 1633, 2201, 1779, 1651, 1646, 2255, 1733, 1714, 1829, 2314, 2130, 2077, 1757, 1706, 1701, 1822, 2072, 1615, 1616, 1871, 1615, 1658, 1646, 1676, 2081, 1668, 1955, 2018, 1767, 1604, 1764, 1673, 1584, 1584, 1584, 1578, 1647, 1587, 1615, 1706, 1738, 1892, 1827, 1891, 1950, 1645, 1593, 1933, 1889, 1826, 2147, 2072, 1844, 1827, 2057, 1773, 1623, 1650, 1638, 1950, 2194, 2142, 1690, 1828, 1655, 1615, 1766, 1768, 1705, 1597, 1638, 1591, 1946, 1950, 1816, 1676, 1950, 1706, 1596, 1574, 1645, 1675, 2062, 1767, 1645, 1669, 1600, 1950, 1931, 1978, 1767, 1767, 1848, 1889, 1889, 2268, 1645, 1556, 1706, 1603, 1584, 1584, 1600, 1947, 1749, 1902, 1767, 1645, 1548, 1653, 1553, 1711, 1950, 1615, 1529, 1521, 1511, 1745, 1554, 1798, 1676, 2434, 1911, 1615, 2081, 1738, 2055, 1584, 2255, 1828, 1582, 1941, 2222, 1950, 1889, 1767, 2133, 1770, 2341, 2134, 1950, 1759, 1864, 1760, 2267, 1974, 2121, 1621, 2041, 1909, 2133, 1969, 2680, 1641, 1579, 1998, 2582, 1567, 1584, 2052, 2316, 2017, 1943, 1522, 1672, 1708, 1975, 1859, 1457, 1523, 1523, 1840, 1893, 1828, 1828, 1648, 1511, 1676, 1550, 1895, 2301, 1661, 2194, 2604, 2022, 2185, 2240, 2256, 1661, 2075, 1782, 1893, 1786, 1767, 1828, 2070, 1950, 1516, 2151, 2020, 1599, 1556, 1831, 1581, 1537, 1523, 1467, 1453, 1907, 1585, 2850, 2466, 2003, 1956, 1821, 1643, 1554, 1511, 2066, 1960, 2106, 1961, 2048, 1645, 1584, 1543, 1462, 1503, 1696, 2682, 1652, 1747, 1447, 1524, 1977, 1459, 1739, 1583, 1523, 1693, 1584, 1466, 1402, 1524, 1463, 2681, 2777, 1531, 2011, 1559, 1706, 2011, 2068, 1563, 2320, 1687, 2328, 1675, 1618, 1280, 1158, 1120, 2044, 1346, 2257, 1767, 2412, 1382, 1462, 1493, 1499, 1531, 2109, 2011, 2438, 2698, 1380, 1380, 1380, 1961, 1560, 1389, 1554, 2012, 2127, 2301, 2255, 2193, 2802, 1529, 2743, 2299, 2006, 2193, 2133, 2198, 2133, 1477, 2343, 1706, 1488, 1463, 1416, 2432, 1525, 1327, 2376, 1405, 2769, 1604, 2778, 1514, 2011, 1341, 1463, 2522, 2057, 1219, 2145, 1767, 1315, 1321, 1402, 1322, 1837, 1112, 1156, 1463, 1112, 1524, 1332, 1584, 1867, 1707, 1828, 2183, 2255, 1421, 1890, 3379, 3048, 1523, 1715, 3007, 2743, 1229, 1478, 1415, 1465, 1838, 1387, 1671, 1332, 1389, 1936, 2777, 1310, 1462, 2527, 2662, 2782, 2399, 1500, 1646, 3034, 1414, 1472, 2794, 1429, 1437, 3413, 1419, 1462, 1117, 3304, 2892, 3352, 1409, 2926, 1584, 1422, 1584, 1394, 1403, 1530, 1525, 1280, 1374, 2133, 3521, 1190, 3433, 3169, 1186, 1280, 1767, 3049, 1950, 1465, 2020, 2309, 2133, 2203, 1161, 1361, 1321, 2674, 1447, 2618, 1584, 1906, 1116, 1463, 1209, 3429, 2843, 1481, 1185, 1280, 1279, 1218, 1228, 1469, 2436, 1273, 1280, 2341, 1315, 1646, 3398, 2804, 1478, 2868, 2218, 1463, 2533, 1645, 1341, 1460, 1317, 1258, 3413, 1583, 1645, 2438, 1521, 3359, 1642, 3628, 1278, 2133, 2252, 2255, 1464, 3108, 2377, 1520, 1448, 1284, 1402, 1493, 1263, 1845, 1402, 3027, 1671, 2897, 3354, 3277, 1608, 1585, 2499, 1547, 1443, 3098, 1706, 2438, 2090, 2537, 1661, 1219, 3271, 3263, 1461, 1358, 3328, 3596, 1767, 3291, 1112, 1218, 2946, 3491, 3610, 1524, 1581, 2568, 1401, 1849, 3364, 1706, 2621, 1719, 1691, 3067, 2855, 1706, 1700, 3014, 3840, 1580, 1963, 2316, 1645, 2098, 3947, 2438, 1535, 3222, 2921, 2103, 1645, 1950, 3348, 3157, 3657, 3967, 2803, 1544, 2438, 2191, 1804, 1448, 2072, 1696, 2670, 2255, 1829, 1399, 4057, 2255, 1645, 1898, 2046, 2008, 3352, 2377, 2895, 1112, 1280, 1995, 2019, 1353, 3058, 1147, 3606, 1390, 2011, 2072, 1768, 2423, 2631, 3102, 2804, 1645, 1396, 1437, 2078, 2292, 2987, 2856, 2240, 2413, 2193, 1439, 1950, 1881, 3257, 3584, 2876, 2011, 2952, 2304, 1367, 1594, 216 ...

# %%
df = pd.DataFrame(elevations)
df.to_csv(f'{root_dir}/daily/input/elevation', index=False, header=False)

# %%
df
# Out:
#          0
# 0     1997
# 1     1891
# 2     2079
# 3     1980
# 4     2011
# ...    ...
# 3846  3231
# 3847  3124
# 3848  3332
# 3849  3207
# 3850  3233
#
# [3851 rows x 1 columns]

# %% [markdown]
# ## Repeat for segments

# %%
gdf = gpd.read_file(root_dir + "GIS/model_nsegment.shp")
gdf
# Out:
#       nhm_seg  model_seg_                                           geometry
# 0       42706           1  LINESTRING (-840513.813 1962765.750, -840463.4...
# 1       42707           2  LINESTRING (-893201.427 1985197.890, -893186.9...
# 2       42708           3  LINESTRING (-855004.607 1970874.926, -855042.8...
# 3       42709           4  LINESTRING (-865168.318 1972729.691, -865089.6...
# 4       42710           5  LINESTRING (-881519.930 1968345.969, -881533.8...
# ...       ...         ...                                                ...
# 1937    44658        1938  LINESTRING (-1202301.007 1565413.836, -1202326...
# 1938    44659        1939  LINESTRING (-1206408.194 1562910.585, -1206329...
# 1939    44660        1940  LINESTRING (-1206307.558 1541303.007, -1206322...
# 1940    44661        1941  LINESTRING (-1198807.062 1540005.963, -1198864...
# 1941    44662        1942  LINESTRING (-958501.055 2003155.072, -958658.8...
#
# [1942 rows x 3 columns]

# %%
invalid_geometries = gdf[~gdf.is_valid]
print(f"Found {len(invalid_geometries)} invalid geometries.")
# Out:
# Found 0 invalid geometries.

# %%
gdf_sorted = gdf.sort_values(by="nhm_seg")
gdf_sorted['nhm_seg'].to_csv(root_dir + 'daily/input/nhm_seg', index=False, header=False)
centroids = gdf_sorted.to_crs(5070).geometry.centroid
centroids_ll = centroids.to_crs(4326)
lats = centroids_ll.y
lons = centroids_ll.x
lats.to_csv(root_dir + 'daily/input/lat_seg.txt', index=False, header=False)
lons.to_csv(root_dir + 'daily/input/lon_seg.txt', index=False, header=False)

# %%
from gdptools import WeightGen
from gdptools import AggGen
from gdptools import ClimRCatData

# %%
gdf = gpd.read_file(root_dir + "GIS/model_nhru.shp")
gdf
# Out:
#       nhm_id  model_hru_                                           geometry
# 0      83301         274  POLYGON ((-1324125.133 1609094.887, -1324275.0...
# 1      83302         275  POLYGON ((-1331914.568 1623225.112, -1331901.0...
# 2      83359         332  POLYGON ((-1308375.036 1622938.630, -1308465.2...
# 3      83364         337  POLYGON ((-1337655.210 1640205.133, -1337535.3...
# 4      83366         339  POLYGON ((-1339634.862 1640985.080, -1339695.0...
# ...      ...         ...                                                ...
# 3846   86611        3556  POLYGON ((-1256384.842 2032365.123, -1256295.1...
# 3847   86615        3560  POLYGON ((-1255034.951 2041934.777, -1255154.7...
# 3848   86686        3631  POLYGON ((-1244805.129 1970954.938, -1244744.9...
# 3849   86691        3636  POLYGON ((-1255664.885 1971375.143, -1255544.7...
# 3850   85616        2561  POLYGON ((-1263404.814 2001224.252, -1263361.8...
#
# [3851 rows x 3 columns]

# %%
climater_cat = "https://github.com/mikejohnson51/climateR-catalogs/releases/download/March-2024/catalog.parquet"
cat = pd.read_parquet(climater_cat)
cat.head()
# Out:
#      id asset                                                URL     type  \
# 0  bcca  None  https://cida.usgs.gov/thredds/dodsC/cmip5_bcca...  opendap
# 1  bcca  None  https://cida.usgs.gov/thredds/dodsC/cmip5_bcca...  opendap
# 2  bcca  None  https://cida.usgs.gov/thredds/dodsC/cmip5_bcca...  opendap
# 3  bcca  None  https://cida.usgs.gov/thredds/dodsC/cmip5_bcca...  opendap
# 4  bcca  None  https://cida.usgs.gov/thredds/dodsC/cmip5_bcca...  opendap
#
#                                         varname variable    description units  \
# 0   BCCA_0-125deg_pr_day_ACCESS1-0_rcp45_r1i1p1       pr  Precipitation  mm/d
# 1   BCCA_0-125deg_pr_day_ACCESS1-0_rcp85_r1i1p1       pr  Precipitation  mm/d
# 2  BCCA_0-125deg_pr_day_bcc-csm1-1_rcp26_r1i1p1       pr  Precipitation  mm/d
# 3  BCCA_0-125deg_pr_day_bcc-csm1-1_rcp45_r1i1p1       pr  Precipitation  mm/d
# 4  BCCA_0-125deg_pr_day_bcc-csm1-1_rcp60_r1i1p1       pr  Precipitation  mm/d
#
#         model ensemble  ...       Y1       Yn   resX   resY  ncols  nrows  \
# 0   ACCESS1-0   r1i1p1  ...  25.1875  52.8125  0.125  0.125  462.0  222.0
# 1   ACCESS1-0   r1i1p1  ...  25.1875  52.8125  0.125  0.125  462.0  222.0
# 2  bcc-csm1-1   r1i1p1  ...  25.1875  52.8125  0.125  0.125  462.0  222.0
# 3  bcc-csm1-1   r1i1p1  ...  25.1875  52.8125  0.125  0.125  462.0  222.0
# 4  bcc-csm1-1   r1i1p1  ...  25.1875  52.8125  0.125  0.125  462.0  222.0
#
#                                                  crs  toptobottom  tiled  \
# 0  +proj=longlat +a=6378137 +f=0.0033528106647474...         True      T
# 1  +proj=longlat +a=6378137 +f=0.0033528106647474...         True      T
# 2  +proj=longlat +a=6378137 +f=0.0033528106647474...         True      T
# 3  +proj=longlat +a=6378137 +f=0.0033528106647474...         True      T
# 4  +proj=longlat +a=6378137 +f=0.0033528106647474...         True      T
#
#    dim_order
# 0        TYX
# 1        TYX
# 2        TYX
# 3        TYX
# 4        TYX
#
# [5 rows x 29 columns]

# %%
_id = "gridmet"
_varname = "tmmx"

# an example query returns a pandas dataframe.
tc = cat.query(
    "id == @_id & variable == @_varname"
)
tc
# Out:
#             id asset                                                URL  \
# 13997  gridmet  None  http://thredds.northwestknowledge.net:8080/thr...
#
#           type                    varname variable description units model  \
# 13997  opendap  daily_maximum_temperature     tmmx        tmmx     K  None
#
#       ensemble  ...    Y1         Yn      resX      resY   ncols  nrows  \
# 13997     None  ...  49.4  25.066667  0.041667  0.041667  1386.0  585.0
#
#                                                      crs  toptobottom  tiled  \
# 13997  +proj=longlat +a=6378137 +f=0.0033528106647474...        False
#
#        dim_order
# 13997        TYX
#
# [1 rows x 29 columns]

# %%
# Create a dictionary of parameter dataframes for each variable
tvars = ["tmmx"]
cat_params = [cat.query("id == @_id & variable == @_var").to_dict(orient="records")[0] for _var in tvars]

cat_dict = dict(zip(tvars, cat_params))

# Output an example of the cat_param.json entry for "aet".
cat_dict.get("tmmx")
# Out:
# {'id': 'gridmet',
#  'asset': None,
#  'URL': 'http://thredds.northwestknowledge.net:8080/thredds/dodsC/agg_met_tmmx_1979_CurrentYear_CONUS.nc',
#  'type': 'opendap',
#  'varname': 'daily_maximum_temperature',
#  'variable': 'tmmx',
#  'description': 'tmmx',
#  'units': 'K',
#  'model': None,
#  'ensemble': None,
#  'scenario': None,
#  'T_name': 'day',
#  'duration': '1979-01-01/..',
#  'interval': '1 days',
#  'nT': nan,
#  'X_name': 'lon',
#  'Y_name': 'lat',
#  'X1': -124.76666663333334,
#  'Xn': -67.05833330000002,
#  'Y1': 49.400000000000006,
#  'Yn': 25.066666666666666,
#  'resX': 0.041666666666666664,
#  'resY': 0.04166666666666668,
#  'ncols': 1386.0,
#  'nrows': 585.0,
#  'crs': '+proj=longlat +a=6378137 +f=0.00335281066474748 +pm=0 +no_defs',
#  'toptobottom': False,
#  'tiled': '',
#  'dim_order': 'TYX'}

# %%
user_data = ClimRCatData(
    cat_dict=cat_dict,
    f_feature=gdf,
    id_feature='nhm_id',
    period=["1980-01-01", "1980-12-31"]
)

wght_gen = WeightGen(
    user_data=user_data,
    method="serial",
    output_file=root_dir + "GIS/uc_weights.csv",
    weight_gen_crs=6931
)

wghts = wght_gen.calculate_weights(intersections=False)
# Out:
# Using serial engine
# grid cells generated in 2.9025 seconds
# Data preparation finished in 3.4918 seconds
# Reprojecting to epsg:EPSG:6931 finished in 0.14 second(s)
# Validating polygons
#      - validating source polygons
#      - fixing 0 invalid polygons.
#      - validating target polygons
#      - fixing 177 invalid polygons.
# Validate polygons finished in 0.1638 seconds
# Intersections finished in 2.7835 seconds
# Weight gen finished in 2.9506 seconds

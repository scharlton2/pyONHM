# %%
import geopandas as gpd
import requests
import pandas as pd

import xarray as xr

# %%
ds = xr.open_dataset('http://thredds.northwestknowledge.net:8080/thredds/dodsC/agg_met_tmmx_1979_CurrentYear_CONUS.nc')
ds
# Out:
# <xarray.Dataset> Size: 54GB
# Dimensions:                    (lat: 585, crs: 1, lon: 1386, day: 16543)
# Coordinates:
#   * lat                        (lat) float64 5kB 49.4 49.36 ... 25.11 25.07
#   * crs                        (crs) float32 4B 3.0
#   * lon                        (lon) float64 11kB -124.8 -124.7 ... -67.1 -67.06
#   * day                        (day) datetime64[ns] 132kB 1979-01-01 ... 2024...
# Data variables:
#     daily_maximum_temperature  (day, lat, lon) float32 54GB ...
# Attributes: (12/19)
#     geospatial_bounds_crs:      EPSG:4326
#     Conventions:                CF-1.0
#     geospatial_bounds:          POLYGON((-124.7666666333333 49.40000000000000...
#     geospatial_lat_min:         25.066666666666666
#     geospatial_lat_max:         49.40000000000000
#     geospatial_lon_min:         -124.7666666333333
#     ...                         ...
#     date:                       02 March 2024
# ...

# %%
http://thredds.northwestknowledge.net:8080/thredds/dodsC/agg_met_tmmx_1979_CurrentYear_CONUS.nc
